# %% [markdown]
# # Explore measurements
#
# Various diagnostic plots to explore our measurements.

# %%
# %matplotlib inline
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy
import seaborn as sns
from skimage import measure # to get contours from masks
import sklearn

import napari
plt.rc('axes', labelsize=18, titlesize=18) 
sns.set_theme()

# %%
os.chdir("D:\Documents\STAGE\Anaphase\Structured")
data = pd.read_csv("Measures_BFf0001_H449pos2_merged.csv", sep=";", comment="#", index_col="idx")
# data = data[data["time_to_anaphase"] >= 0].dropna()
data = data[data["time"] > 0].dropna()

print(data.shape)
data.head()
# Out:
# (1861, 25)
#      frame  time  mom_ID  daugh_ID       mom_x       mom_y     daugh_x  \
# idx
# 0       18     1    11.0     808.0  371.062921  331.552239  363.365629
# 0       19     2    11.0     808.0  371.495880  331.623188  363.063983
# 0       20     3    11.0     808.0  371.800227  331.260870  363.057890
# 0       21     4    11.0     808.0  370.928592  331.567164  362.200747
# 0       22     5    11.0     808.0  372.133561  331.000000  363.010271
#
#         daugh_y    mom_surf  daugh_surf  ...  daugh_ecc  relat_ecc  mom_circ  \
# idx                                      ...
# 0    323.352941  191.299472    8.534336  ...   0.820408   1.023012  0.847407
# 0    323.421053  196.299472   11.250034  ...   0.830933   0.998219  0.843124
# 0    323.047619  196.299472   13.681430  ...   0.938263   1.195639  0.843124
# 0    323.142857  192.583774   14.965732  ...   0.856876   1.053357  0.872175
# 0    322.904762  193.015171   16.397129  ...   0.925441   1.101654  0.811349
#
#      daugh_circ  relat_circ  inter_centroid_dist  \
# idx
# 0      0.816201    0.963175            10.630146
# 0      0.852575    1.011209            12.041595
# 0      0.776800    0.921335            12.041595
# 0      0.920806    1.055758            11.313708
# 0      0.861788    1.062168            12.727922
#
#      relat_inter_centroid_distance  anaphase  time_to_anaphase  movie_name
# idx
# 0                         0.244912     False                32   H449_pos2
# 0                         0.274090     False                31   H449_pos2
# 0                         0.264806     False                30   H449_pos2
# 0                         0.252302     False                29   H449_pos2
# 0                         0.281578     False                28   H449_pos2
#
# [5 rows x 25 columns]

# %%
print(data["daugh_per"])
# Out:
# idx
# 0      11.462814
# 0      12.877028
# 0      14.877028
# 0      14.291241
# 0      15.462814
#          ...
# 137    36.190659
# 137    38.190660
# 137    38.776446
# 137    37.604874
# 137    40.190660
# Name: daugh_per, Length: 1861, dtype: float64

# %% [markdown]
# # 1. Single feature exploration

# %%
h449, bf0001 = data[data["movie_name"] == "H449_pos2"], data[data["movie_name"] == "BF_f0001"]
print(h449.shape, bf0001.shape)
print(data["daugh_per"].std(), h449["daugh_per"].std(), bf0001["daugh_per"].std())
# Out:
# (1071, 25) (790, 25)
# 7.381182656157113 6.6076093070330275 6.782582987561143

# %%
import matplotlib.colors as mcolors

# get matplotlib colors
by_hsv = [(tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                 name)
                for name, color in mcolors.TABLEAU_COLORS.items()]
names = [name for hsv, name in by_hsv]

fig, ax = plt.subplots(4, 2, figsize=(30, 25))

feature = "daugh_per"

# make boxplot on the first axis
vals, anaph, times, xs = [], [], [], []
for i, time in enumerate(data["time"].unique()):
    if time < 65: # do not append outliers
        d = data[data["time"] == time]
        vals.append(d[feature].values)
        anaph.append(d["anaphase"].values)
        times.append(str(time))
        xs.append(np.random.normal(i + 1, 0.04, d[feature].values.shape[0]))  # adds jitter to the data points - can be adjusted
    
ax[0][0].boxplot(vals, labels=times)
ax[0][0].set_ylabel(feature)
ax[0][0].set_title(f"Boxplot of {feature} over time (box: first to third quartile)")


for x, val, an, col in zip(xs, vals, anaph, names):  # add scatter plots to on the boxplots
    for jitter, v, a in zip(x, val, an):
        if a:
            ax[0][0].scatter(jitter, v, alpha=1, c="g", s=50, marker="*")
        else:
            ax[0][0].scatter(jitter, v, alpha=0.2, c="r", s=15)
    
ax[0][0].set_xlabel("time (min)")

# plot individual trajectories on the second axis
for idx in data.index.unique():
    event = data.loc[idx]
    
    # plot surface over time
#     if event[event["time"] == 6]["relat_surf"].values[0] > 0.2:
    ax[0][1].plot(event["time"], event[feature], c=names[idx % len(names)], alpha=0.5)

    # plot anaphase moment
    dx, dy = np.random.normal(0, 0.1, 1), np.random.normal(0, 0.01, 1)
    anaphase_moment = event[event["anaphase"]]
    ax[0][1].scatter(anaphase_moment["time"] + dx, anaphase_moment[feature] + dy, marker="*", s=60, c=names[idx % len(names)])
    
ax[0][1].plot(data["time"].unique(), data.groupby("time")[feature].mean(), "--", c="black", label="mean")

ax[0][1].legend()
# ax[0][1].set_xlim(0, 60)
ax[0][1].set_xlabel("time (min)")
ax[0][1].set_ylabel(feature)
ax[0][1].set_title("Relative daughter cell / mom cell, over time")

# Conditional distributions on the third axis
will_divide = data[data["time_to_anaphase"] > 0]
is_dividing = data[data["time_to_anaphase"] == 0]

ax[1][0].scatter(will_divide["time"], [0 for i in range(will_divide["time"].shape[0])], c="r", label="Before division")
ax[1][0].scatter(is_dividing["time"], [1 for i in range(is_dividing["time"].shape[0])], c="g", label="During division")
ax[1][0].legend()
ax[1][0].set_xlabel("Elapsed time since bud detection")
ax[1][0].set_ylabel("Is dividing")
ax[1][0].set_yticks([0, 1])
ax[1][0].set_title("Elapsed time before/during cell division.")

# scatter plot on the fourth axis
ax[1][1].scatter(will_divide[feature], [0 for i in range(will_divide[feature].shape[0])], c="r", label="Before division")
ax[1][1].scatter(is_dividing[feature], [1 for i in range(is_dividing[feature].shape[0])], c="g", label="During division")
ax[1][1].legend()
ax[1][1].set_xlabel(feature)
ax[1][1].set_ylabel("Is dividing")
ax[1][1].set_yticks([0, 1])
ax[1][1].set_title("Surfaces of the dividing/non dividing cells.")

# Time-to-anaphase (TTA) as a function of the feature (relative surface)
# data[features] = (data[features] - data[features].mean()) / data[features].std() # dataset-wise standardization
# features = []
# for idx, traj in data.groupby(level=0):
#     traj_mean, traj_std = traj[feature].mean(), traj[feature].std()
#     for t in traj.time:
#         features.append((traj[traj["time"] == t][feature] - traj_mean) / traj_std)
        
# data[feature] = features
        
for idx in data.index.unique():
    event = data.loc[idx]
    # plot surface over time
    ax[2][0].scatter(event[event["time_to_anaphase"] >= 0][feature], event[event["time_to_anaphase"] >= 0]["time_to_anaphase"], s=75, c=names[idx % len(names)], alpha=1)
    
ax[2][0].legend()
ax[2][0].set_xlabel(feature)
ax[2][0].set_ylabel("TTA")
ax[2][0].set_title("Time to anaphase (TTA) as a function of surface")

# plot TTA=f(cumulative surfaces) 
for idx in data.index.unique():
    event = data.loc[idx]
    
    # plot cumulative surface over time
    ax[2][1].plot(event[event["time_to_anaphase"] >= 0][feature], event[event["time_to_anaphase"] >= 0]["time_to_anaphase"], c=names[idx % len(names)], alpha=1)
    
ax[2][1].legend()
ax[2][1].set_xlabel(feature)
ax[2][1].set_ylabel("TTA")
ax[2][1].set_title("Time to anaphase (TTA) as a function of cumulative relative surface")

# plot TTA=f(cumulative surfaces) 
proportion_of_preevent = []
total_number_of_events = data.index.unique().shape[0]
step = 0.
while step < 0.9:
    at_this_surf = data[(step < data[feature]) & (data[feature] < step + 0.1)]
    pre_event, divided = at_this_surf[at_this_surf["time_to_anaphase"] > 0], at_this_surf[at_this_surf["time_to_anaphase"] <= 0]
    if pre_event.shape[0] == 0:
        proportion_of_preevent.append(0)
    else:
        proportion_of_preevent.append(pre_event.shape[0] / (pre_event.shape[0] + divided.shape[0]))  # proportion of cells which didn't divide yet
    step += 0.1
    
kaplan_meier_estimate = []
step = 0.
while step < 0.9:
    at_this_surf = data[(step < data[feature]) & (data[feature] < step + 0.1)]
    survived_and_didnt_divide, survived_and_divided = at_this_surf[at_this_surf["time_to_anaphase"] > 0], at_this_surf[at_this_surf["time_to_anaphase"] == 0]
    if survived_and_didnt_divide.shape[0] != 0:
        kaplan_meier_estimate.append(np.prod(kaplan_meier_estimate) * (1 - survived_and_divided.shape[0] / (survived_and_didnt_divide.shape[0] + survived_and_divided.shape[0])))  # proportion of cells which didn't divide yet
    else:
        kaplan_meier_estimate.append(0)
    step += 0.1    
    
ax[3][0].plot([0.1 * k + 0.05 for k in range(10)], kaplan_meier_estimate, label="Survival function")

ax[3][0].legend()
ax[3][0].set_xlabel(feature)
ax[3][0].set_ylabel("Kaplan-Meier Estimate")
ax[3][0].set_title("Kaplan-Meier estimate for the surface, i.e. S\hat(s) = P(Surface at anaphase is greater than s)")

# Survival time distribution estimation : P(S > t)_{t >= 0}
kaplan_meier_estimate = []
for t in data["time"].unique():
    at_this_time = data[data["time"] == t]
    survived_and_didnt_divide, survived_and_divided = at_this_time[at_this_time["time_to_anaphase"] > 0], at_this_time[at_this_time["time_to_anaphase"] == 0]
    if survived_and_didnt_divide.shape[0] != 0:
        kaplan_meier_estimate.append(np.prod(kaplan_meier_estimate) * (1 - survived_and_divided.shape[0] / (survived_and_didnt_divide.shape[0] + survived_and_divided.shape[0])))  # proportion of cells which didn't divide yet
    else:
        kaplan_meier_estimate.append(0)
    
ax[3][1].plot(data["time"].unique(), kaplan_meier_estimate, label="Survival function")

ax[3][1].legend()
ax[3][1].set_xlabel("relative time (min)")
ax[3][1].set_ylabel("Kaplan-Meier Estimate")
ax[3][1].set_title("Proportion of cells which didn't divide yet, i.e. S\hat(t) = P(TTA > t)")

save_fig = False
if save_fig:
    plt.savefig("Description_BF_f0001_division_events.pdf", format="pdf")
# Out:
# C:\Users\Hugo\anaconda3\envs\deep_learning.py\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# plot individual trajectories on the second axis
# for idx in data.index.unique():
#     event = data.loc[idx]
    
#     # plot surface over time
# #     if event[event["time"] == 6]["relat_surf"].values[0] > 0.2:
#     ax.plot(event["time"], event[feature], c=names[idx % len(names)], alpha=0.5)

#     # plot anaphase moment
#     dx, dy = np.random.normal(0, 0.1, 1), np.random.normal(0, 0.01, 1)
#     anaphase_moment = event[event["anaphase"]]
#     ax.scatter(anaphase_moment["time"] + dx, anaphase_moment[feature] + dy, marker="*", s=60, c=names[idx % len(names)])
    
# ax.plot(data["time"].unique(), data.groupby("time")[feature].mean(), "--", c="black", label="mean")
print(data.groupby("time")["daugh_per"].std().min(), data.groupby("time")["daugh_per"].std())
# Out:
# 0.4258934843865923 time
# 1     2.509074
# 2     2.734664
# 3     2.359153
# 4     2.610769
# 5     2.838072
# 6     3.404645
# 7     2.788138
# 8     3.100242
# 9     3.014664
# 10    2.685287
# 11    3.085463
# 12    3.446182
# 13    2.858254
# 14    2.969441
# 15    2.781577
# 16    2.910385
# 17    2.875564
# 18    2.927687
# 19    2.629316
# 20    2.356250
# 21    2.157658
# 22    2.083301
# 23    1.927897
# 24    2.903107
# 25    1.797429
# 26    1.851085
# 27    1.491937
# 28    1.478657
# 29    1.552541
# 30    3.114080
# 31    1.508527
# 32    1.897131
# 33    1.421817
# 34    1.537130
# 35    1.825742
# 36    3.453959
# 37    1.492904
# 38    0.425893
# 39         NaN
# 40         NaN
# 41         NaN
# 42    3.368286
# 43         NaN
# 48    3.384289
# 54    3.750742
# 60    4.440130
# 66    3.825102
# 72    3.238108
# 78    2.524416
# Name: daugh_per, dtype: float64

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))

plt.rc('axes', labelsize=20, titlesize=20) 

feature = "daugh_per"

# indexes = np.random.choice(data.index.unique(), size=75)

# for idx in data.index.unique():
for idx in indexes:
    event = data.loc[idx]
    
    # plot cumulative surface over time
    ax.plot(event[event["time_to_anaphase"] >= 0][feature], event[event["time_to_anaphase"] >= 0]["time_to_anaphase"], c=names[idx % len(names)], alpha=1)

min_per, max_per, n_intervals = data[data["time_to_anaphase"] >= 0]["daugh_per"].min(), data[data["time_to_anaphase"] >= 0]["daugh_per"].max(), 20
delta, k = (max_per - min_per) / n_intervals, 0
print(delta)
mean_per, std_per = [], []
while min_per + k * delta < max_per:
    event = data[(data["time_to_anaphase"] >= 0) & (min_per + k * delta <= data["daugh_per"]) & (data["daugh_per"] <= min_per + (k+1) * delta)]
    mean_per.append([data["daugh_per"].mean(), event["time_to_anaphase"].mean()])
    std_per.append([data["daugh_per"].mean(), event["time_to_anaphase"].std()])
    k += 1
mean_per = np.array(mean_per)
std_per = np.array(std_per)

# ax.plot(data.groupby(feature)[feature], data.groupby(feature)["time_to_anaphase"].mean(), "--", c="black", label="mean")
    
ax.legend()
ax.set_xlabel("Daughter cell perimeter (px)")
ax.set_ylabel("Time to Anaphase (min)")
# ax.set_title("Time to anaphase (TTA) as a function of cumulative relative surface")

# ax.legend()
# ax.set_xlim(0, 60)
# ax.set_xlabel("Time (min)")
# ax.set_ylabel("Daughter perimeter (px)")
fig.tight_layout()
# ax[0][1].set_title("Relative daughter cell / mom cell, over time")
os.chdir("D:/Documents/STAGE/Rapport/Images")
plt.savefig("tta_vs_daughter_perimeter.pdf", format="pdf")
# Out:
# No handles with labels found to put in legend.
# 1.731370264291763

# %% [markdown]
# # 2. Correlations between features

# %%
# features
features = ["time",
            "daugh_surf",
            "daugh_per",
            "daugh_ecc",
            "daugh_circ",
            "inter_centroid_dist",
            "anaphase",
           ]

df = data[features]

df.head()

already_seen = []

from scipy.stats import pearsonr, spearmanr
def corrfunc(x, y, ax=None, **kws):
    """Plot the correlation coefficient in the top left hand corner of a plot."""
    if not (x.name, y.name) in already_seen:
        r, _ = spearmanr(x, y)
        ax = ax or plt.gca()
        ax.annotate(f'ρ = {r:.2f}', xy=(.1, .9), xycoords=ax.transAxes, fontsize="large")
        already_seen.append((x.name, y.name))

plt.rc('axes', labelsize=18, titlesize=20) 

os.chdir("D:/Documents/STAGE/Rapport/Images")

heatmap = False
if heatmap:
    corr = df.corr(method="pearson")
    corr.style.background_gradient(cmap='coolwarm') # This line plots nicely visualized matrix of correlation
    fig, ax = plt.subplots(1, 1,figsize=(12, 12))
    sns.heatmap(corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(20, 220, n=200), square=True, ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
    save_fig = False
    if save_fig:
        plt.savefig("heatmap_relative_features.pdf", format="pdf")
else: # pairplot
    g = sns.pairplot(df, hue="anaphase", diag_kind="hist")
    g.map(corrfunc)
    save_fig = False
    if save_fig:
        plt.savefig("pairplot_daughter_features.pdf", format="pdf")
