# %% [markdown]
# # Generate piwel-wise weight maps
#
# In order to train our network properly, with an emphasis on the learning of the cells borders, we want to use our usual loss (Jaccard) and multiply it by a map which gives more weight to the border pixels.
#
# $$L(\hat{y})  = L_{Jac}(\hat{y}, y) \times  $$
