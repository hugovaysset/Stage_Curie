# %% [markdown]
# # Tracking with btrack
#
# Duration : 120 images with confluent cells in the end and pretty crowded in the beginning -> 352 s.

# %%
import cv2
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy
from skimage import measure # to get contours from masks

# btrack module and configuration file
import btrack
from btrack.dataio import localizations_to_objects
from btrack.constants import BayesianUpdates
from btrack.render import plot_tracks

import imagecodecs
import napari
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\napari\_qt\__init__.py:37: UserWarning:
#     napari was tested with QT library `>=5.12.3`.
#     The version installed is 5.9.7. Please report any issues with this
#     specific QT version at https://github.com/Napari/napari/issues.
#
#   warn(message=warn_message)

# %% [markdown]
# ## I. Load segmentation results
#
# Attention : les prédictions sont encodées en float32 bits (sortie du réseau de neurones...).

# %%
os.chdir("D:/Hugo/Anaphase/Inter_Div_Correlation/")  # root dir containg Predictions and Images Path
predictions_path = "S-Voronoi_H449_pos2_1-300_substract.tif"
corresponding_imgs = "BF_1-300_512x512.tif"

predictions = imageio.volread(predictions_path)
imgs = imageio.volread(corresponding_imgs)

print(predictions.shape, imgs.shape)

# plot images and masks
nb_imgs = 4
fig, ax = plt.subplots(1, nb_imgs, figsize=(16, 10))
for i, im in enumerate(imgs[:nb_imgs]):
    ax[i].imshow(imgs[i], cmap="Spectral")
    ax[i].imshow(predictions[i], cmap="Spectral", alpha=0.4)
    plt.axis("off")

plt.tight_layout()

# Cast to 8-bit depth images prior to thresholding
u8_predictions = []
for p in predictions:
    u8_p = p - p.min()
    u8_p = u8_p / u8_p.max() * 255
    u8_predictions.append(np.uint8(u8_p))
u8_predictions = np.array(u8_predictions)
# Out:
# (300, 512, 512) (300, 512, 512)

# %% [markdown]
# ## II. Get contours
#
# ### Thresholding to get the masks

# %%
threshold = 200
_, masks = cv2.threshold(u8_predictions, threshold, 255, cv2.THRESH_BINARY) # threshold : seuil / masks : images seuillees

print(masks.dtype) # masks are 8-bit

# plot images and masks
nb_imgs = 4
fig, ax = plt.subplots(1, nb_imgs, figsize=(16, 10))
for i, im in enumerate(imgs[:nb_imgs]):
    ax[i].imshow(imgs[i], cmap="Spectral")
    ax[i].imshow(masks[i], cmap="Spectral", alpha=0.4)
    plt.axis("off")

plt.tight_layout()
# Out:
# uint8

# %%
print(masks.shape)
# Out:
# (300, 512, 512)

# %% [markdown]
# ### Retrieve contours using skimage

# %%
import matplotlib.colors as mcolors
by_hsv = [(tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in mcolors.TABLEAU_COLORS.items()]
names = [name for hsv, name in by_hsv]
# Way easier to get contours in skimage than with opencv..!
all_contours = []
for m in masks:
    c = measure.find_contours(m, threshold)
    all_contours.append(np.array(c)) #threshold is defined when thresholding
all_contours = np.array(all_contours)

print(all_contours.shape)

# Display the images and plot all contours found
nb_imgs = 1
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

for i, (contour_im, im) in enumerate(zip(all_contours[2:3], imgs[2:3])):
    ax.imshow(cv2.resize(im, (512, 512)), cmap="gray", origin="lower")
    for i, contour in enumerate(contour_im):
        ax.plot(contour[:, 1], contour[:, 0], linewidth=5, c=names[i % len(names)])
    ax.axis("off")
# Out:
# <ipython-input-5-f40990d29e15>:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   all_contours.append(np.array(c)) #threshold is defined when thresholding
# <ipython-input-5-f40990d29e15>:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   all_contours = np.array(all_contours)
# (300,)

# %% [markdown]
# ## III. Peform tracking using the surface and position of each cell at each time point
#
# ### Get the barycenter (position) of each cell at each time point and store them in a DataFrame

# %%
# retrieve all barycenters and shape a datastructure for btrack
positions_at_frames = []
for i, frame in enumerate(all_contours):
    for cell in frame:
        positions_at_frames.append({"t": i, "x": np.sum(cell[:, 1]) / cell.shape[0], "y": np.sum(cell[:, 0]) / cell.shape[0], "Contours": cell})
positions_per_frame = pd.DataFrame(positions_at_frames)

# check the shape
print(positions_per_frame.shape)
positions_per_frame.head()

# Display the image and plot the barycenters to check if they're correct
nb_imgs = 4
fig, ax = plt.subplots(1, nb_imgs, figsize=(20, 20))

for i, (contour_im, im) in enumerate(zip(all_contours[:nb_imgs], imgs[:nb_imgs])):
    ax[i].imshow(cv2.resize(im, (512, 512)), cmap="gray", origin="lower")
    for idx, cell in positions_per_frame[positions_per_frame["t"] == i].iterrows():
        x, y = cell["x"], cell["y"]
        ax[i].scatter(x, y)
    ax[i].axis("off")
# Out:
# (360801, 4)

# %% [markdown]
# ### Run position-based tracking with btrack

# %%
import time

# os.chdir("D:/Hugo/Python_Scripts/Notebooks")
MODE = BayesianUpdates.EXACT # APPROXIMATE or EXACT
objects = localizations_to_objects(positions_per_frame)
objects[0]

t0 = time.time()

# initialise a tracker session using a context manager
with btrack.BayesianTracker() as tracker:

  # configure the tracker using a config file (example config file used here)
    tracker.configure_from_file("config_file.json")

  # set the update method and maximum search radius (both optional)
    tracker.update_method = MODE
#     tracker.max_search_radius = 50

    # append the objects to be tracked
    tracker.append(objects)

    # set the volume (Z axis volume is set very large for 2D data)
#     tracker.volume=((0,600),(0,800),(-1e5,1e5))
    tracker.volume=((0,600),(0,600),(-1e5,1e5))

    # track them (in interactive mode)
    tracker.track_interactive(step_size=100)

    # generate hypotheses and run the global optimiser
#     tracker.optimize()  # veeeeery slow

    # get the tracks as a python list
    tracks = tracker.tracks
    box = tracker.volume
    
tf = time.time()
print(f"Tracking duration : {round(tf - t0, 2)} seconds.")
# Out:
# [INFO][2021/05/25 04:10:00 PM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2021/05/25 04:10:02 PM] Loaded btrack: C:\ProgramData\Anaconda3\lib\site-packages\btrack\libs\libtracker.DLL
# [INFO][2021/05/25 04:10:02 PM] btrack (v0.4.0) library imported
# [INFO][2021/05/25 04:10:02 PM] Setting max XYZ search radius to: 100
# [INFO][2021/05/25 04:10:02 PM] Starting BayesianTracker session
# [INFO][2021/05/25 04:10:02 PM] Loading configuration file: config_file.json
# [INFO][2021/05/25 04:10:02 PM] Loading motion model: b'cell_motion'
# [INFO][2021/05/25 04:10:02 PM] Setting Bayesian update method to: BayesianUpdates.EXACT
# [INFO][2021/05/25 04:10:02 PM] Objects are of type: <class 'list'>
# [INFO][2021/05/25 04:10:02 PM] Set volume to ((0, 600), (0, 600), (-100000.0, 100000.0))
# [INFO][2021/05/25 04:10:02 PM] Starting tracking...
# [INFO][2021/05/25 04:10:03 PM] Tracking objects in frames 0 to 99 (of 300)...
# [INFO][2021/05/25 04:11:04 PM]  - Timing (Bayesian updates: 1159.00ms, Linking: 10.00ms)
# [INFO][2021/05/25 04:11:04 PM]  - Probabilities (Link: 1.00000, Lost: 0.33445)
# [INFO][2021/05/25 04:11:04 PM]  - Stats (Active: 1362, Lost: 5135, Conflicts resolved: 6700)
# [INFO][2021/05/25 04:11:04 PM] Tracking objects in frames 100 to 199 (of 300)...
# [INFO][2021/05/25 04:13:34 PM]  - Timing (Bayesian updates: 1597.00ms, Linking: 13.00ms)
# [INFO][2021/05/25 04:13:34 PM]  - Probabilities (Link: 1.00000, Lost: 0.01245)
# [INFO][2021/05/25 04:13:34 PM]  - Stats (Active: 1585, Lost: 15522, Conflicts resolved: 20031)
# [INFO][2021/05/25 04:13:34 PM] Tracking objects in frames 200 to 299 (of 300)...
# [INFO][2021/05/25 04:16:34 PM]  - Timing (Bayesian updates: 1768.00ms, Linking: 10.00ms)
# [INFO][2021/05/25 04:16:34 PM]  - Probabilities (Link: 0.82512, Lost: 0.01289)
# [INFO][2021/05/25 04:16:34 PM] SUCCESS.
# [INFO][2021/05/25 04:16:34 PM]  - Found 10855 tracks in 300 frames (in 0.0s)
# [INFO][2021/05/25 04:16:34 PM]  - Inserted 8852 dummy objects to fill tracking gaps
# [INFO][2021/05/25 04:16:35 PM] Ending BayesianTracker session
# Tracking duration : 393.34 seconds.

# %%
# plot the tracks in 3D
plot_tracks(tracks, order='xyt', box=box)

# %% [markdown]
# ### Interactive view of the tracking results with napari

# %%
# Convert from the btrack format (data structure == OrderedDict) into a format that is accepted by Napari (i.e. numpy array)
tracks_to_napari = []
for track in tracks:
    for i, frame in enumerate(track.t):
        tracks_to_napari.append({"ID": track.ID, "Frame": frame, "X": track.y[i], "Y": track.x[i]})
tracks_to_napari = pd.DataFrame(tracks_to_napari)

print(tracks_to_napari.shape)
print(tracks_to_napari[:10])
# Out:
# (369652, 4)
#    ID  Frame           X           Y
# 0   1      0  364.144135  226.964912
# 1   1      1  365.071452  227.050847
# 2   1      2  366.495339  227.491803
# 3   1      3  366.478946  227.606557
# 4   1      4  366.560913  225.622951
# 5   1      5  367.560913  225.672131
# 6   1      6  367.056416  226.122807
# 7   1      7  368.444334  226.050847
# 8   1      8  367.396978  225.655738
# 9   1      9  367.462552  225.655738

# %%
resized = []
for im in imgs:
    resized.append(cv2.resize(im, (512, 512)))
resized = np.array(resized)

with napari.gui_qt():
    viewer = napari.view_image(resized)
    viewer.add_image(u8_predictions, opacity=0.5, colormap="blue", blending="additive")
    viewer.add_tracks(tracks_to_napari)

# %% [markdown]
# ### Retrieve the contours of each cell over time
# Here one line corresponds to one cell, at one frame. We want to add the contours of that cell (previously computed from the masks) at the same line.

# %%
# ou bien les contours n'existent pas des le debut (non segmentes, peu probable), ou bien sont vides en sortie de findContours()
# mais je pense qu'ils sont toujours retrouves a cette etape

# retrieve contours from tracks
tracks_and_contours, contours = [], []
for idx, track in tracks_to_napari.iterrows():
    
    if idx % 1000 == 0: # monitoring progress
        print(f"Number of analyzed lines: {idx}")
        
    # retrieve the contours corresponding to this track at this frame (one cell only)
    mask = ((positions_per_frame["t"] == track["Frame"]) & (track["X"] == positions_per_frame["y"]) & (track["Y"] == positions_per_frame["x"]))
    corresponding_contours = positions_per_frame[mask]["Contours"]
    tracks_and_contours.append({"ID": track["ID"], "Frame": track["Frame"], "X": track["X"], "Y": track["Y"], "Contours": corresponding_contours})
    try:  ## je pense que l'erreur (certaines cellules disparaissent ponctuellement en video parfois) vient de la
        contours.append(corresponding_contours.to_numpy()[0])
    except:
#         print(f"An error occured: {corresponding_contours}")  # always empty dataframe
        contours.append([])

tracks_and_contours = pd.DataFrame(tracks_and_contours)
contours = np.array(contours)

print(tracks_and_contours.shape, contours.shape)
tracks_and_contours.head()
# Out:
# Number of analyzed lines: 0
# Number of analyzed lines: 1000
# Number of analyzed lines: 2000
# Number of analyzed lines: 3000
# Number of analyzed lines: 4000
# Number of analyzed lines: 5000
# Number of analyzed lines: 6000
# Number of analyzed lines: 7000
# Number of analyzed lines: 8000
# Number of analyzed lines: 9000
# Number of analyzed lines: 10000
# Number of analyzed lines: 11000
# Number of analyzed lines: 12000
# Number of analyzed lines: 13000
# Number of analyzed lines: 14000
# Number of analyzed lines: 15000
# Number of analyzed lines: 16000
# Number of analyzed lines: 17000
# Number of analyzed lines: 18000
# Number of analyzed lines: 19000
# Number of analyzed lines: 20000
# Number of analyzed lines: 21000
# Number of analyzed lines: 22000
# Number of analyzed lines: 23000
# Number of analyzed lines: 24000
# Number of analyzed lines: 25000
# Number of analyzed lines: 26000
# Number of analyzed lines: 27000
# Number of analyzed lines: 28000
# Number of analyzed lines: 29000
# Number of analyzed lines: 30000
# Number of analyzed lines: 31000
# Number of analyzed lines: 32000
# Number of analyzed lines: 33000
# Number of analyzed lines: 34000
# Number of analyzed lines: 35000
# Number of analyzed lines: 36000
# Number of analyzed lines: 37000
# Number of analyzed lines: 38000
# Number of analyzed lines: 39000
# Number of analyzed lines: 40000
# Number of analyzed lines: 41000
# Number of analyzed lines: 42000
# Number of analyzed lines: 43000
# Number of analyzed lines: 44000
# Number of analyzed lines: 45000
# Number of analyzed lines: 46000
# Number of analyzed lines: 47000
# Number of analyzed lines: 48000
# Number of analyzed lines: 49000
# Number of analyzed lines: 50000
# Number of analyzed lines: 51000
# Number of analyzed lines: 52000
# Number of analyzed lines: 53000
# Number of analyzed lines: 54000
# Number of analyzed lines: 55000
# Number of analyzed lines: 56000
# Number of analyzed lines: 57000
# Number of analyzed lines: 58000
# Number of analyzed lines: 59000
# Number of analyzed lines: 60000
# Number of analyzed lines: 61000
# Number of analyzed lines: 62000
# Number of analyzed lines: 63000
# Number of analyzed lines: 64000
# Number of analyzed lines: 65000
# Number of analyzed lines: 66000
# Number of analyzed lines: 67000
# Number of analyzed lines: 68000
# Number of analyzed lines: 69000
# Number of analyzed lines: 70000
# Number of analyzed lines: 71000
# Number of analyzed lines: 72000
# Number of analyzed lines: 73000
# Number of analyzed lines: 282000
# Number of analyzed lines: 283000
# Number of analyzed lines: 284000
# Number of analyzed lines: 285000
# Number of analyzed lines: 286000
# Number of analyzed lines: 287000
# Number of analyzed lines: 288000
# Number of analyzed lines: 289000
# Number of analyzed lines: 290000
# Number of analyzed lines: 291000
# Number of analyzed lines: 292000
# Number of analyzed lines: 293000
# Number of analyzed lines: 294000
# Number of analyzed lines: 295000
# Number of analyzed lines: 296000
# Number of analyzed lines: 297000
# Number of analyzed lines: 298000
# Number of analyzed lines: 299000
# Number of analyzed lines: 300000
# Number of analyzed lines: 301000
# Number of analyzed lines: 302000
# Number of analyzed lines: 303000
# Number of analyzed lines: 304000
# Number of analyzed lines: 305000
# Number of analyzed lines: 306000
# Number of analyzed lines: 307000
# Number of analyzed lines: 308000
# Number of analyzed lines: 309000
# Number of analyzed lines: 310000
# Number of analyzed lines: 311000
# Number of analyzed lines: 312000
# Number of analyzed lines: 313000
# Number of analyzed lines: 314000
# Number of analyzed lines: 315000
# Number of analyzed lines: 316000
# Number of analyzed lines: 317000
# Number of analyzed lines: 318000
# Number of analyzed lines: 319000
# Number of analyzed lines: 320000
# Number of analyzed lines: 321000
# Number of analyzed lines: 322000
# Number of analyzed lines: 323000
# Number of analyzed lines: 324000
# Number of analyzed lines: 325000
# Number of analyzed lines: 326000
# Number of analyzed lines: 327000
# Number of analyzed lines: 328000
# Number of analyzed lines: 329000
# Number of analyzed lines: 330000
# Number of analyzed lines: 331000
# Number of analyzed lines: 332000
# Number of analyzed lines: 333000
# Number of analyzed lines: 334000
# Number of analyzed lines: 335000
# Number of analyzed lines: 336000
# Number of analyzed lines: 337000
# Number of analyzed lines: 338000
# Number of analyzed lines: 339000
# Number of analyzed lines: 340000
# Number of analyzed lines: 341000
# Number of analyzed lines: 342000
# Number of analyzed lines: 343000
# Number of analyzed lines: 344000
# Number of analyzed lines: 345000
# Number of analyzed lines: 346000
# Number of analyzed lines: 347000
# Number of analyzed lines: 348000
# Number of analyzed lines: 349000
# Number of analyzed lines: 350000
# Number of analyzed lines: 351000
# Number of analyzed lines: 352000
# Number of analyzed lines: 353000
# Number of analyzed lines: 354000
# Number of analyzed lines: 355000
# Number of analyzed lines: 356000
# Number of analyzed lines: 357000
# Number of analyzed lines: 358000
# Number of analyzed lines: 359000
# Number of analyzed lines: 360000
# Number of analyzed lines: 361000
# Number of analyzed lines: 362000
# Number of analyzed lines: 363000
# Number of analyzed lines: 364000
# Number of analyzed lines: 365000
# Number of analyzed lines: 366000
# Number of analyzed lines: 367000
# Number of analyzed lines: 368000
# Number of analyzed lines: 369000
# (369652, 5) (369652,)
# <ipython-input-18-52b3e3814ba0>:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   contours = np.array(contours)
#     ID  Frame           X           Y  \
# 0  1.0    0.0  364.144135  226.964912
# 1  1.0    1.0  365.071452  227.050847
# 2  1.0    2.0  366.495339  227.491803
# 3  1.0    3.0  366.478946  227.606557
# 4  1.0    4.0  366.560913  225.622951
#
#                                             Contours
# 0  328    [[371.2156862745098, 230.0], [371.21568...
# 1  834    [[372.2156862745098, 230.0], [372.21568...
# 2  1347    [[374.2156862745098, 229.0], [374.2156...
# 3  1871    [[374.2156862745098, 229.0], [374.2156...
# 4  2399    [[374.2156862745098, 227.0], [374.2156...

# %%
# # get matplotlib colors
# import matplotlib.colors as mcolors
# by_hsv = [(tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
#                          name)
#                         for name, color in mcolors.CSS4_COLORS.items()]
# names = [name for hsv, name in by_hsv]

# # Display the image and plot the barycenters to check if they're correct
# nb_imgs = 4
# fig, ax = plt.subplots(1, nb_imgs, figsize=(20, 6))
# for i, im in enumerate(imgs[:nb_imgs]):
#     ax[i].imshow(cv2.resize(im, (512, 512)), cmap="gray", origin="lower")
#     at_this_frame = tracks_and_contours[tracks_and_contours["Frame"] == i]
#     for idx, cell in at_this_frame.iterrows():
#         x, y = cell["Y"], cell["X"]
#         ax[i].scatter(x, y, c=names[(i + idx) % len(names)], s=2)
#         contour = cell["Contours"].items()
#         for _, cont in contour:
#             for point in cont:
#                 ax[i].plot(point[1], point[0], ".", c=names[(i + idx) % len(names)], markersize=1)
#     ax[i].axis("off")

# fig.tight_layout()
# fig.suptitle("Bright-field images, with the barycenter and the contours of each cell")
# Out:
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-13-f4e274955123> in <module>
#      14     for idx, cell in at_this_frame.iterrows():
#      15         x, y = cell["Y"], cell["X"]
# ---> 16         ax[i].scatter(x, y, c=names[(i + idx) % len(names)], s=2)
#      17         contour = cell["Contours"].items()
#      18         for _, cont in contour:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4515                 self.set_ymargin(0.05)
#    4516
# -> 4517         self.add_collection(collection)
#    4518         self._request_autoscale_view()
#    4519
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_collection(self, collection, autolim)
#    1932             # Make sure viewLim is not stale (mostly to match
#    1933             # pre-lazy-autoscale behavior, which is not really better).
# -> 1934             self._unstale_viewLim()
#    1935             self.update_datalim(collection.get_datalim(self.transData))
#    1936
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _unstale_viewLim(self)
#     645             for ax in self._shared_y_axes.get_siblings(self):
#     646                 ax._stale_viewlim_y = False
# --> 647             self.autoscale_view(scalex=scalex, scaley=scaley)
#     648
#     649     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2494             # `get_children` would raise an AttributeError.
#    2495             if self._xmargin and scalex and self._autoscaleXon:
# -> 2496                 x_stickies = np.sort(np.concatenate([
#    2497                     artist.sticky_edges.x
#    2498                     for ax in self._shared_x_axes.get_siblings(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#    2495             if self._xmargin and scalex and self._autoscaleXon:
#    2496                 x_stickies = np.sort(np.concatenate([
# -> 2497                     artist.sticky_edges.x
#    2498                     for ax in self._shared_x_axes.get_siblings(self)
#    2499                     if hasattr(ax, "lines")
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the Tracking results (DataFrame) and the contours (npy) to files

# %%
# Save the tracking results in a csv (without contours)
save_path = "Tracking_Results_H449_pos2_1-300.csv"
tracks_and_contours.drop("Contours", axis=1).to_csv(save_path, sep=",")

# Save the contours in numpy text file
save_path = "Tracking_Results_H449_pos2_1-300.npy"
np.save(save_path, contours)
